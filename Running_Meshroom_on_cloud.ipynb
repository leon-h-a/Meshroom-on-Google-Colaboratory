# %% [markdown]
# <a href="https://colab.research.google.com/github/leon-h-a/Meshroom-on-Google-Colaboratory/blob/main/Running_Meshroom_on_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Runtime > Change runtime type > Set "Hardware accelerator" to "GPU"

# %%
from IPython.display import clear_output

# mount drive with images
from google.colab import drive
drive.mount('/content/drive')
clear_output()

# %%
from IPython.display import clear_output

# get Meshroom  
# !wget -N https://github.com/alicevision/meshroom/releases/download/v2019.1.0/Meshroom-2019.1.0-linux.tar.gz
# !mkdir meshroom
# !tar xzf Meshroom-2019.1.0-linux.tar.gz -C ./meshroom
clear_output()

# %%
# run meshrrom
# !./meshroom/Meshroom-2019.1.0/meshroom_photogrammetry --input ./drive/MyDrive/brake_cylinder --output ./object_out

# %%
# zip and export
from google.colab import files
from IPython.display import clear_output

# !zip -r meshobject.zip ./object_out
files.download('meshobject.zip')
clear_output()
